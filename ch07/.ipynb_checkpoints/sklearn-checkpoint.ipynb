# %%
# Scikit-Learn regression and classification

# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame(index=pd.date_range('2000', '2020'))
df['BookPressure'] = np.random.randn(len(df)) * 2
df['TradePressure'] = np.random.randn(len(df)) * 100
df['RelativeValue'] = np.random.randn(len(df)) * 50
df['Microstructure'] = np.random.randn(len(df)) * 10

true_coefficients = np.random.randint(low=-100, high=101, size=4) / 10
df['PriceChange'] = ((df['BookPressure'] * true_coefficients[0])
+ (df['TradePressure'] * true_coefficients[1])
+ (df['RelativeValue'] * true_coefficients[2])
+ (df['Microstructure'] * true_coefficients[3])
+ (np.random.randn(len(df)) * 200))

df['Price'] = df['PriceChange'].cumsum(0) + 100000
# Out:
# (array([10. ,  6.2, -0.9,  5. ]),
#              BookPressure  TradePressure  RelativeValue  Microstructure  \
#  2000-01-01      4.545869      -2.335894       5.953205      -15.025576
#  2000-01-02     -0.302344    -186.764283       9.150213       13.795346
#  2000-01-03      0.305826     109.750983      28.405901        3.154499
#  2000-01-04     -4.881166      60.166421      28.573366        0.991316
#  2000-01-05      0.151594       8.887189      37.196261      -12.575052
#  ...                  ...            ...            ...             ...
#  2019-12-28      0.991224     -64.759167     -11.788173       -8.232611
#  2019-12-29     -0.732954     -63.094109     -53.199767       13.592050
#  2019-12-30      1.497534     -13.859112     -52.662387        9.479166
#  2019-12-31     -1.890265    -113.704752      60.258456       12.229772
#  2020-01-01      1.657811     -77.354049     -39.090108       -3.294086
#
#              PriceChange          Price
#  2000-01-01  -263.749500   99736.250500
#  2000-01-02  -758.298833   98977.951667
#  2000-01-03   296.415621   99274.367288
#  2000-01-04   128.611671   99402.978959
#  2000-01-05  -110.967033   99292.011927
#  ...                 ...            ...
#  2019-12-28  -696.566631  182969.852518
#  2019-12-29  -141.027810  182828.824709
#  2019-12-30   293.802584  183122.627293
#  2019-12-31  -295.295108  182827.332185
#  2020-01-01  -204.576735  182622.755450
#
#  [7306 rows x 6 columns])

# %%
true_coefficients
# Out:
# array([10. ,  6.2, -0.9,  5. ])

# %%
df
# Out:
#             BookPressure  TradePressure  RelativeValue  Microstructure  \
# 2000-01-01      4.545869      -2.335894       5.953205      -15.025576
# 2000-01-02     -0.302344    -186.764283       9.150213       13.795346
# 2000-01-03      0.305826     109.750983      28.405901        3.154499
# 2000-01-04     -4.881166      60.166421      28.573366        0.991316
# 2000-01-05      0.151594       8.887189      37.196261      -12.575052
# ...                  ...            ...            ...             ...
# 2019-12-28      0.991224     -64.759167     -11.788173       -8.232611
# 2019-12-29     -0.732954     -63.094109     -53.199767       13.592050
# 2019-12-30      1.497534     -13.859112     -52.662387        9.479166
# 2019-12-31     -1.890265    -113.704752      60.258456       12.229772
# 2020-01-01      1.657811     -77.354049     -39.090108       -3.294086
#
#             PriceChange          Price      PredPrice        Errors  \
# 2000-01-01  -263.749500   99736.250500   99961.011495 -2.247610e+02
# 2000-01-02  -758.298833   98977.951667   98862.549185  1.154025e+02
# 2000-01-03   296.415621   99274.367288   99540.585912 -2.662186e+02
# 2000-01-04   128.611671   99402.978959   99841.834419 -4.388555e+02
# 2000-01-05  -110.967033   99292.011927   99806.128674 -5.141167e+02
# ...                 ...            ...            ...           ...
# 2019-12-28  -696.566631  182969.852518  184025.188237 -1.055336e+03
# 2019-12-29  -141.027810  182828.824709  183746.700552 -9.178758e+02
# 2019-12-30   293.802584  183122.627293  183777.964916 -6.553376e+02
# 2019-12-31  -295.295108  182827.332185  183059.625653 -2.322935e+02
# 2020-01-01  -204.576735  182622.755450  182622.755450  5.820766e-11
#
#             DiscretePriceChange  PredDiscretePriceChange
# 2000-01-01                    0                        0
# 2000-01-02                   -1                       -1
# 2000-01-03                    0                        1
# 2000-01-04                    0                        0
# 2000-01-05                    0                        0
# ...                         ...                      ...
# 2019-12-28                   -1                       -1
# 2019-12-29                    0                        0
# 2019-12-30                    0                        0
# 2019-12-31                    0                       -1
# 2020-01-01                    0                       -1
#
# [7306 rows x 10 columns]

# %%
df['Price'].plot(figsize=(12, 6), color='black', legend='Price')

# %%
pd.plotting.scatter_matrix(df.drop('Price', axis=1), color='black', alpha=0.2, grid=True, diagonal='kde', figsize=(10, 10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f4592c105f8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f45923e9e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f459256f0b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4592520320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f45924d5588>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f45924887f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f459243ba58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4592471c88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4592471cf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f45923791d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f459232c438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f45922e06a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4592294908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f45922c9b70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f459227ddd8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f4592240080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f45921f12e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f45921a5550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f45921587b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f459210ca20>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f4592140c88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f45920f6ef0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f45920b7198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4592068400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f459201e668>]],
#       dtype=object)

# %%
# Regression

# %%
features = df[['BookPressure', 'TradePressure', 'RelativeValue', 'Microstructure']]
target = df['PriceChange']

# %%
from sklearn.linear_model import RidgeCV
ridge = RidgeCV()
ridge.fit(features, target)
# Out:
# RidgeCV(alphas=array([ 0.1,  1. , 10. ]), cv=None, fit_intercept=True,
#         gcv_mode=None, normalize=False, scoring=None, store_cv_values=False)

# %%
true_coefficients, ridge.coef_
# Out:
# (array([10. ,  6.2, -0.9,  5. ]),
#  array([11.21856334,  6.20641632, -0.93444009,  4.94581522]))

# %%
ridge.score(features, target)
# Out:
# 0.9076861352499385

# %%
df['PredPrice'] = ridge.predict(features).cumsum(0) + 100000; df
# Out:
#             BookPressure  TradePressure  RelativeValue  Microstructure  \
# 2000-01-01      4.545869      -2.335894       5.953205      -15.025576
# 2000-01-02     -0.302344    -186.764283       9.150213       13.795346
# 2000-01-03      0.305826     109.750983      28.405901        3.154499
# 2000-01-04     -4.881166      60.166421      28.573366        0.991316
# 2000-01-05      0.151594       8.887189      37.196261      -12.575052
# ...                  ...            ...            ...             ...
# 2019-12-28      0.991224     -64.759167     -11.788173       -8.232611
# 2019-12-29     -0.732954     -63.094109     -53.199767       13.592050
# 2019-12-30      1.497534     -13.859112     -52.662387        9.479166
# 2019-12-31     -1.890265    -113.704752      60.258456       12.229772
# 2020-01-01      1.657811     -77.354049     -39.090108       -3.294086
#
#             PriceChange          Price      PredPrice
# 2000-01-01  -263.749500   99736.250500   99961.011495
# 2000-01-02  -758.298833   98977.951667   98862.549185
# 2000-01-03   296.415621   99274.367288   99540.585912
# 2000-01-04   128.611671   99402.978959   99841.834419
# 2000-01-05  -110.967033   99292.011927   99806.128674
# ...                 ...            ...            ...
# 2019-12-28  -696.566631  182969.852518  184025.188237
# 2019-12-29  -141.027810  182828.824709  183746.700552
# 2019-12-30   293.802584  183122.627293  183777.964916
# 2019-12-31  -295.295108  182827.332185  183059.625653
# 2020-01-01  -204.576735  182622.755450  182622.755450
#
# [7306 rows x 7 columns]

# %%
df['Price'].plot(figsize=(12, 6), color='gray', linestyle='--', legend='Price')
df['PredPrice'].plot(figsize=(12, 6), color='black', linestyle='-.', legend='PredPrice')

# %%
df['Price'].loc['2010-01-01':'2010-03-31'].plot(figsize=(12, 6), color='darkgray', linestyle='-', legend='Price')
df['PredPrice'].loc['2010-01-01':'2010-03-31'].plot(figsize=(12, 6), color='black', linestyle='-.', legend='PredPrice')

# %%
df['Errors'] = df['Price'] - df['PredPrice']
df['Errors'].plot(figsize=(12, 6), kind='kde', color='black', legend='Errors')

# %%
# Classification

# %%
target_discrete = pd.cut(target, bins=5, labels=[-2, -1, 0, 1, 2]).astype(int); target_discrete
# Out:
# 2000-01-01    0
# 2000-01-02   -1
# 2000-01-03    0
# 2000-01-04    0
# 2000-01-05    0
#              ..
# 2019-12-28   -1
# 2019-12-29    0
# 2019-12-30    0
# 2019-12-31    0
# 2020-01-01    0
# Freq: D, Name: PriceChange, Length: 7306, dtype: int64

# %%
target_discrete.plot(figsize=(12, 6), kind='hist', color='black')

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(max_depth=5)
rf.fit(features, target_discrete)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=5, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
rf.score(features, target_discrete)
# Out:
# 0.835340815767862

# %%
df['DiscretePriceChange'] = target_discrete
df['PredDiscretePriceChange'] = rf.predict(features)
df
# Out:
#             BookPressure  TradePressure  RelativeValue  Microstructure  \
# 2000-01-01      4.545869      -2.335894       5.953205      -15.025576
# 2000-01-02     -0.302344    -186.764283       9.150213       13.795346
# 2000-01-03      0.305826     109.750983      28.405901        3.154499
# 2000-01-04     -4.881166      60.166421      28.573366        0.991316
# 2000-01-05      0.151594       8.887189      37.196261      -12.575052
# ...                  ...            ...            ...             ...
# 2019-12-28      0.991224     -64.759167     -11.788173       -8.232611
# 2019-12-29     -0.732954     -63.094109     -53.199767       13.592050
# 2019-12-30      1.497534     -13.859112     -52.662387        9.479166
# 2019-12-31     -1.890265    -113.704752      60.258456       12.229772
# 2020-01-01      1.657811     -77.354049     -39.090108       -3.294086
#
#             PriceChange          Price      PredPrice        Errors  \
# 2000-01-01  -263.749500   99736.250500   99961.011495 -2.247610e+02
# 2000-01-02  -758.298833   98977.951667   98862.549185  1.154025e+02
# 2000-01-03   296.415621   99274.367288   99540.585912 -2.662186e+02
# 2000-01-04   128.611671   99402.978959   99841.834419 -4.388555e+02
# 2000-01-05  -110.967033   99292.011927   99806.128674 -5.141167e+02
# ...                 ...            ...            ...           ...
# 2019-12-28  -696.566631  182969.852518  184025.188237 -1.055336e+03
# 2019-12-29  -141.027810  182828.824709  183746.700552 -9.178758e+02
# 2019-12-30   293.802584  183122.627293  183777.964916 -6.553376e+02
# 2019-12-31  -295.295108  182827.332185  183059.625653 -2.322935e+02
# 2020-01-01  -204.576735  182622.755450  182622.755450  5.820766e-11
#
#             DiscretePriceChange  PredDiscretePriceChange
# 2000-01-01                    0                        0
# 2000-01-02                   -1                       -1
# 2000-01-03                    0                        1
# 2000-01-04                    0                        0
# 2000-01-05                    0                        0
# ...                         ...                      ...
# 2019-12-28                   -1                       -1
# 2019-12-29                    0                        0
# 2019-12-30                    0                        0
# 2019-12-31                    0                       -1
# 2020-01-01                    0                       -1
#
# [7306 rows x 10 columns]

# %%
df['DiscretePriceChange'].loc['2010-01-01':'2010-03-31'].plot(figsize=(12, 6), color='darkgray', linestyle='-', legend='Price')
df['PredDiscretePriceChange'].loc['2010-01-01':'2010-03-31'].plot(figsize=(12, 6), color='black', linestyle='-.', legend='PredPrice')

# %%
df['ClassificationErrors'] = df['DiscretePriceChange'] - df['PredDiscretePriceChange']
df['ClassificationErrors'].plot(figsize=(12, 6), kind='kde', color='black', legend='ClassificationErrors')
